// %% [markdown]
// ### Ejercicio P1 — Mi lista de películas favoritas

// %% [markdown]
// Crea una `List[String]` con al menos seis títulos de películas. A continuación:
//
// - Imprime cuántas películas hay en la lista.
// - Imprime la primera y la última película.
// - Imprime la lista ordenada alfabéticamente.
// - Comprueba si una película concreta (tú decides el título) está en la lista.
//
// **Salida de referencia** *(los títulos son un ejemplo)*:

// %%
val peliculas = List(
  "El bueno, el feo y el malo",
  "Sin perdón",
  "Hasta que llegó su hora",
  "Valor de ley",
  "Solo ante el peligro",
  "Los siete magníficos",
  "Bailando con lobos",
  "Grupo salvaje",
  "Río Bravo",
  "La diligencia"
)



// 1. Imprime cuántas películas hay
println(s"Total de películas: ${peliculas.size}")

// 2. Imprime la primera y la última
println(s"Primera: ${peliculas.head}")
println(s"Última:  ${peliculas.last}")

// 3. Imprime la lista ordenada alfabéticamente
// El método .sorted crea una NUEVA lista ordenada
println(s"Ordenada: ${peliculas.sorted}")

// 4. Comprueba si una película concreta está en la lista
val buscar = "Grupo salvaje"
println(s"¿Está '$buscar'? ${peliculas.contains(buscar)}")
// Out:
// Total de películas: 10
// Primera: El bueno, el feo y el malo
// Última:  La diligencia
// Ordenada: List(Bailando con lobos, El bueno, el feo y el malo, Grupo salvaje, Hasta que llegó su hora, La diligencia, Los siete magníficos, Río Bravo, Sin perdón, Solo ante el peligro, Valor de ley)
// ¿Está 'Grupo salvaje'? true
// peliculas: List[String] = List(
//   "El bueno, el feo y el malo",
//   "Sin perdón",
//   "Hasta que llegó su hora",
//   "Valor de ley",
//   "Solo ante el peligro",
//   "Los siete magníficos",
//   "Bailando con lobos",
//   "Grupo salvaje",
//   "Río Bravo",
//   "La diligencia"
// )
// buscar: String = "Grupo salvaje"

// %% [markdown]
// ### Ejercicio P2 — Termómetro de invierno

// %% [markdown]
// Tienes las temperaturas mínimas registradas durante una semana (en °C):
//
// ```
// -3.0, 1.5, -0.5, 4.2, -2.1, 0.8, 3.3
// ```
//
// Con esa `List[Double]`:
//
// - Imprime cuántos días se registraron temperaturas **bajo cero**.
// - Imprime la temperatura mínima y la máxima de la semana.
// - Imprime la media semanal con dos decimales.
//
// **Salida de referencia:**
//
// ```
// Días bajo cero: 3
// Temperatura mínima: -3.0°C
// Temperatura máxima: 4.2°C
// Media semanal: 0.46°C
// ```

// %%
val temps = List(-3.0, 1.5, -0.5, 4.2, -2.1, 0.8, 3.3)

// 1. Días bajo cero (contamos los menores que 0)
val bajoCero = temps.count(_ < 0)
println(s"Días bajo cero: $bajoCero")

// 2. Mínima y máxima
println(s"Temperatura mínima: ${temps.min}°C")
println(s"Temperatura máxima: ${temps.max}°C")

// 3. Media semanal
// sumamos todo y dividimos por el total de elementos
val media = temps.sum / temps.size
println(f"Media semanal: $media%.2f°C")
// Out:
// Días bajo cero: 3
// Temperatura mínima: -3.0°C
// Temperatura máxima: 4.2°C
// Media semanal: 0,60°C
// temps: List[Double] = List(-3.0, 1.5, -0.5, 4.2, -2.1, 0.8, 3.3)
// bajoCero: Int = 3
// media: Double = 0.6
