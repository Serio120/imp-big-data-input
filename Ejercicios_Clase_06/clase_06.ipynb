// %% [markdown]
// ### Una buena practica, es comprobar la versión de Scala que tenemos en el kernel de este notebook.

// %%
scala.util.Properties.versionString
// Out:
// res1: String = "version 2.13.18"

// %% [markdown]
// ### Tipos de datos primitivos

// %%
val edad: Int        = 30
val precio: Double   = 99.99
val activo: Boolean  = true
val inicial: Char    = 'S'
val lenguaje: String = "Scala"
// Out:
// edad: Int = 30
// precio: Double = 99.99
// activo: Boolean = true
// inicial: Char = 'S'
// lenguaje: String = "Scala"

// %% [markdown]
// ### Unit es el tipo de retorno de cualquier función que solo produce un efecto

// %%
// Ejemplo 1 de Unit .

def saludar(nombre: String): Unit =
  println(s"Hola, $nombre!")

saludar("Ana")
// Hola, Ana!

// Ejemplo 2 de Unit .

def imprimirLinea(longitud: Int): Unit =
  println("-" * longitud)

imprimirLinea(80)
// ------------------------------
// el kernel muestra: ()
// Out:
// Hola, Ana!
// --------------------------------------------------------------------------------
// defined function saludar
// defined function imprimirLinea

// %% [markdown]
// ### Float — precisión simple (32 bits, ~7 dígitos significativos). Se declara con el sufijo f:

// %%
val precio: Float = 3.14159265358979f
println(precio)
// 3.1415927   ← solo 7 dígitos, el resto se pierde
// Out:
// 3.1415927
// precio: Float = 3.1415927F
