// %%
// Ejercicio 1
println("Mariano")
// Out:
// Mariano

// %%
// Ejercicio 2
val a = 10
val b = 20
println(10 + 20)
// Out:
// 30
// a: Int = 10
// b: Int = 20

// %%
// Ejercicio 3
val datos = List(2,4,6)
println(datos.map(_*2))
// Out:
// List(4, 8, 12)
// datos: List[Int] = List(2, 4, 6)
