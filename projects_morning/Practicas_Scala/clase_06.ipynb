// %% [markdown]
// # Buena Práctica
//
// ## Comprobar Version Scala de este kernel

// %%
scala.util.Properties.versionString
// Out:
// res2: String = "version 2.13.18"

// %% [markdown]
// # Tipos de datos primitivos

// %%
val edad: Int        = 30
val precio: Double   = 99.99
val activo: Boolean  = true
val inicial: Char    = 'S'
val lenguaje: String = "Scala"
// Out:
// edad: Int = 30
// precio: Double = 99.99
// activo: Boolean = true
// inicial: Char = 'S'
// lenguaje: String = "Scala"
